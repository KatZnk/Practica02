# %%
import sys
sys.path.append('../src')

# %%
import ejercicio5
peso = float(input("Ingrese el peso del paquete (kg): "))
zona = input('Ingrese la zona de destino (local/regional/nacional): ').lower().strip()
print(ejercicio5.costo_envio(peso, zona))
# Out:
# Costo de envio: $4500
