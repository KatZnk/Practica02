# %%
import sys
sys.path.append('../src')

# %%
import ejercicio7

lista_nombres = [pal.strip(" .,").lower() for pal in input("Ingrese los participantes (separados por coma): ").split(",")]
names = set(lista_nombres)

ejercicio7.sorteo(names)
# Out:
# Sorteo de amigo invisible:
# sofia → loui
# loui → clara
# clara → ka
# ka → sabrina
# sabrina → martina
# martina → taylor
# taylor → alycia
# alycia → sofia
